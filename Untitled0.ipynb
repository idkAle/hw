# %%
fv = float(input("What is your target goal?"))
num_years = float(input("How many years will you invest?"))
interest_rate = float(input("What wil the interest rate be"))

present_value = fv/(1+interest_rate)**num_years
print("The present value is", present_value)
# Out:
# What is your target goal?5000
# How many years will you invest?1000
# What wil the interest rate be.23
# The present value is 6.220976559560127e-87

# %% [markdown]
# This program tells you how much you need to invest oer a period of time to reach your targeted goal.

# %%
fv = float(input("How much will you invest?"))

present_value = fv/(1+.35)**5
print("The present value is", present_value)
# Out:
# How much will you invest?2000
# The present value is 446.0270040080403

# %% [markdown]
# This program shows much your investment will grow over 5 years.
